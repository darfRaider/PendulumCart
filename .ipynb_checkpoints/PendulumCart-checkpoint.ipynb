# %% [markdown]
# # Pendulum on chart

# %% [markdown]
# ## Includes

# %%
# %matplotlib inline
import numpy as np
import sympy as sp
from scipy.integrate import odeint
from scipy.linalg import expm

from matplotlib import pyplot as plt
from matplotlib import animation as ani
from IPython.display import HTML

# %% [markdown]
# ## Init symbols and funtions

# %%
t, m, M, l, g, Fb = sp.symbols('t m M l g Fb' )
x = sp.Function('x')(t)
theta = sp.Function('theta')(t)
F = sp.Function('F')(t)

# Generalized coordinates
z1 = sp.Function('z1')(t)
z2 = sp.Function('z2')(t)
z3 = sp.Function('z3')(t)
z4 = sp.Function('z4')(t)
states = [z1,z2,z3,z4]
u  = sp.Function('u')(t)
inputs = [u]

# %% [markdown]
# ## Penulum on chart equations

# %% [markdown]
# Position of cart and mass

# %%
xc = x
xm = x+l*sp.sin(theta)
ym = -l*sp.cos(theta)

# %% [markdown]
# Velocity of cart and mass

# %%
dxc = xc.diff(t)
dxm = xm.diff(t)
dym = ym.diff(t)

# %% [markdown]
# Acceleration of cart and mass

# %%
ddxc = dxc.diff(t)
ddxm = dxm.diff(t)
ddym = dym.diff(t)

# %% [markdown]
# Newtons law $\quad m \ddot{x}(t) = \sum_i F_i$

# %%
eqCx = -m*ddxc + F + Fb*sp.sin(theta)
eqMx = -M*ddxm - Fb*sp.sin(theta)
eqMy = -M*ddym + Fb*sp.cos(theta) - M*g

# %% [markdown]
# Eliminate $F_b$ and obtain two equations of motion

# %%
Fb_eqn = (eqMx/sp.sin(theta)+Fb).simplify()
EOM1 = eqCx.subs({Fb: Fb_eqn}).simplify()
EOM2 = (eqMx*sp.cos(theta)+eqMy*sp.sin(theta)).simplify()

# %%
EOM1
# Out:
# M*l*sin(theta(t))*Derivative(theta(t), t)**2 - M*l*cos(theta(t))*Derivative(theta(t), (t, 2)) - M*Derivative(x(t), (t, 2)) - m*Derivative(x(t), (t, 2)) + F(t)

# %%
EOM2
# Out:
# -M*(g*sin(theta(t)) + l*Derivative(theta(t), (t, 2)) + cos(theta(t))*Derivative(x(t), (t, 2)))

# %% [markdown]
# ## Generalized coordinates

# %%
genCoords = {x:             z1, 
             x.diff(t):     z2, 
             theta:         z3, 
             theta.diff(t): z4, 
             F:              u}
sp.pprint(genCoords)
# Out:
# ⎧                                      d                d              ⎫
# ⎨F(t): u(t), θ(t): z₃(t), x(t): z₁(t), ──(θ(t)): z₄(t), ──(x(t)): z₂(t)⎬
# ⎩                                      dt               dt             ⎭

# %% [markdown]
# ### Substitute into equations

# %%
gEOM1 = EOM1.subs(genCoords)
gEOM1
# Out:
# M*l*z4(t)**2*sin(z3(t)) - M*l*cos(z3(t))*Derivative(z4(t), t) - M*Derivative(z2(t), t) - m*Derivative(z2(t), t) + u(t)

# %%
gEOM2 = EOM2.subs(genCoords)
gEOM2
# Out:
# -M*(g*sin(z3(t)) + l*Derivative(z4(t), t) + cos(z3(t))*Derivative(z2(t), t))

# %% [markdown]
# ## Obtain the form $\dot{z}(t) = f(z)$

# %% [markdown]
# Solve EOM2 for $\dot{z}_2$ and $\dot{z}_4$,

# %%
sol_dz4 = sp.solve(gEOM2,z4.diff(t))[0]
sol_dz4
# Out:
# -(g*sin(z3(t)) + cos(z3(t))*Derivative(z2(t), t))/l

# %%
sol_dz2 = sp.solve(gEOM2,z2.diff(t))[0]
sol_dz2
# Out:
# -g*tan(z3(t)) - l*Derivative(z4(t), t)/cos(z3(t))

# %% [markdown]
# Substitute $\dot{z}_2$ and $\dot{z}_4$ into EOM1

# %%
EQ_dz2 = gEOM1.subs({z4.diff(t):sol_dz4}).simplify()
EQ_dz2 = sp.solve(EQ_dz2,z2.diff(t))[0]
EQ_dz2
# Out:
# (M*g*sin(2*z3(t))/2 + M*l*z4(t)**2*sin(z3(t)) + u(t))/(M*sin(z3(t))**2 + m)

# %%
EQ_dz4 = gEOM1.subs({z2.diff(t):sol_dz2}).simplify()
EQ_dz4 = sp.solve(EQ_dz4,z4.diff(t))[0]
EQ_dz4
# Out:
# -(M*g*sin(z3(t)) + M*l*z4(t)**2*sin(2*z3(t))/2 + g*m*sin(z3(t)) + u(t)*cos(z3(t)))/(l*(M*sin(z3(t))**2 + m))

# %% [markdown]
# Get desired nonlinear vector valued function $f(z)$ such that $\dot{z} = f(z)$

# %%
f = []
f.append(z2)
f.append(EQ_dz2)
f.append(z4)
f.append(EQ_dz4)
f
# Out:
# [z2(t),
#  (M*g*sin(2*z3(t))/2 + M*l*z4(t)**2*sin(z3(t)) + u(t))/(M*sin(z3(t))**2 + m),
#  z4(t),
#  -(M*g*sin(z3(t)) + M*l*z4(t)**2*sin(2*z3(t))/2 + g*m*sin(z3(t)) + u(t)*cos(z3(t)))/(l*(M*sin(z3(t))**2 + m))]

# %%
states
values = [1,2,3,4]
d = dict(zip(states,values))
d
# Out:
# {z1(t): 1, z2(t): 2, z3(t): 3, z4(t): 4}

# %%
class NLDiffEQN:
    # List of state variables
    states = None
    nStates = 0
    # List of input variables
    inputs = None
    nInputs = 0
    # Equilibrium point
    eqPoint = None
    
    # Dict of constants in equations
    constants = None
    
    # List of symbolic nonlinear equations
    equationsNL = None
    nEquations = 0
    # List of symbolic nonlinear equations (constants substituted)
    equationsNLc = None
    
    # A and B matrix of linear, time-varying, continuous system
    Acltv = None
    Bcltv = None
    Acltvc = None
    Bcltvc = None
    
    # Constructor
    def __init__(self,equations,states,inputs,eqPoint,constants = dict({})):
        self.equationsNL = equations
        self.equationsNLc = [0]*len(equations)
        self.nEquations = len(equations)
        if len(constants) != 0:
            for i, e in enumerate(equations):
                self.equationsNLc[i] = e.subs(constants)
        self.states = states
        self.nStates = len(states)
        self.inputs = inputs
        self.nInputs = len(inputs)
        self.eqPoint = eqPoint
        self.constants = constants
        
        # Compute continuous time, linear, time-varying system
        self.setLTI()
    
        
    def dfdtNL(self,zv,t,uv):
        res = [0]*len(zv)
        z = dict(zip(self.states,zv))
        u = dict(zip(self.inputs,uv))
        for i, e in enumerate(self.equationsNLc):
            res[i] = e.subs(z).subs(u).evalf()
        return res
    
    def setLTI(self):
        nz = self.nStates
        nu = self.nInputs
        # Init A and B matrix
        A = [[0 for x in range(nz)] for y in range(nz)]
        B = [[0 for x in range(nu)] for y in range(nz)]
    
        # Linearize system
        for i, eq in enumerate(self.equationsNL):
            # Populate A matrix
            for j, z in enumerate(self.states):
                A[i][j] = eq.diff(z).subs(self.constants)
            # Populate B matrix
            for j, u in enumerate(self.inputs):
                B[i][j] = eq.diff(u).subs(self.constants)
        
        # continuous-time timeinvariant system
        self.A = sp.Matrix(A)
        self.B = sp.Matrix(B)
        self.Alti = sp.Matrix(A).subs(self.eqPoint)
        self.Blti = sp.Matrix(B).subs(self.eqPoint)
        
        # TODO: Discretize system here
    
    def dfdtLTI(self,zv,t,uv):
        zd = dict(zip(self.states,zv))
        ud = dict(zip(self.inputs,uv))
        
        z = sp.Matrix(zv);
        u = sp.Matrix(uv);
        res = self.Alti*z + self.Blti*u
        return list(res.evalf())
    
    def LTIdEuler(self,t,zv,uv):
        Ts = t[1]-t[0]
        A = np.identity(4)+np.array(Ts*self.Alti)
        B = np.array(Ts*self.Blti)
        res = np.zeros((len(t),4))
        res[0,:] = zv
        for i in range(len(t)-1):
            res[i+1,:] = np.dot(A,res[i,:])+np.dot(B,uv)
        return res
    
    def LTIdExact(self,t,zv,uv):
        Ts = t[1]-t[0]
        print(self.Alti)
        A = expm(np.array(Ts*self.Alti))
        B = self.Alti.inv()*(A-np.eye(4))*np.array(self.Blti)
        res = np.zeros((len(t),4))
        res[0,:] = zv
        for i in range(len(t)-1):
            res[i+1,:] = np.dot(A,res[i,:])+np.dot(B,uv)
        return res

# %%
const = dict({M: 1,
              m: 10,
              g: 9.81,
              l: 1})
EQ_point = {z1: 0, z2: 0, z3: 0, z4: 0, u: 0}
z0 = [0,0,0.5,0]
u0 = [0.5]
Nt = 200
tmax = 5
t = np.linspace(0, tmax, Nt)
nldiff = NLDiffEQN(f,[z1, z2, z3, z4],[u],EQ_point,const)

# %%
import scipy as sci
K = np.array(sp.Matrix([[1,2],[3,4]]))
sci.linalg.expm(K)
# Out:
# array([[ 51.9689562 ,  74.73656457],
#        [112.10484685, 164.07380305]])

# %%
nldiff.Bltid
nldiff.Altid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-9932d9a7bdd8> in <module>
# ----> 1 nldiff.Bltid
#       2 nldiff.Altid
#
# AttributeError: 'NLDiffEQN' object has no attribute 'Bltid'

# %%
nldiff.dfdtNL(z0, 0, u0)
# Out:
# [0, 0.452344433398930, 0, -5.10013412042631]

# %%
resLTId_exact = nldiff.LTIdExact(t,z0,u0)
# Out:
# Matrix([[0, 1, 0, 0], [0, 0, 0.981000000000000, 0], [0, 0, 0, 1], [0, 0, -10.7910000000000, 0]])
# ---------------------------------------------------------------------------
# NonInvertibleMatrixError                  Traceback (most recent call last)
# <ipython-input-62-ac3ce8e3aae3> in <module>
# ----> 1 resLTId_exact = nldiff.LTIdExact(t,z0,u0)
#
# <ipython-input-57-cc265ff32b46> in LTIdExact(self, t, zv, uv)
#      98         print(self.Alti)
#      99         A = expm(np.array(Ts*self.Alti))
# --> 100         B = self.Alti.inv()*(A-np.eye(4))*np.array(self.Blti)
#     101         res = np.zeros((len(t),4))
#     102         res[0,:] = zv
#
# ~/.local/lib/python3.5/site-packages/sympy/matrices/matrices.py in inv(self, method, **kwargs)
#    3670         if method is not None:
#    3671             kwargs['method'] = method
# -> 3672         return self._eval_inverse(**kwargs)
#    3673
#    3674     def is_nilpotent(self):
#
# ~/.local/lib/python3.5/site-packages/sympy/matrices/dense.py in _eval_inverse(self, **kwargs)
#     263         M = self.as_mutable()
#     264         if method == "GE":
# --> 265             rv = M.inverse_GE(iszerofunc=iszerofunc)
#     266         elif method == "LU":
#     267             rv = M.inverse_LU(iszerofunc=iszerofunc)
#
# ~/.local/lib/python3.5/site-packages/sympy/matrices/matrices.py in inverse_GE(self, iszerofunc)
#    3585         red = big.rref(iszerofunc=iszerofunc, simplify=True)[0]
#    3586         if any(iszerofunc(red[j, j]) for j in range(red.rows)):
# -> 3587             raise NonInvertibleMatrixError("Matrix det == 0; not invertible.")
#    3588
#    3589         return self._new(red[:, big.rows:])
#
# NonInvertibleMatrixError: Matrix det == 0; not invertible.

# %%
resNL = odeint(nldiff.dfdtNL, z0, t, args=(u0,))
resLTI = odeint(nldiff.dfdtLTI, z0, t, args=(u0,))
resLTId = nldiff.LTIdEuler(t,z0,u0)

# %%
res = [resNL, resLTI, resLTId]
#res = [resL]

# %%
def drawCartPendulum(i, data, col, ax):
    # Chart position
    xc = data[i,0]
    yc = 0
    ax1.scatter(xc,yc,s=40,c=col)
    
    # Position of mass
    theta = data[i,2]
    xm = xc+np.sin(theta)
    ym = -np.cos(theta)
    ax1.scatter(xm,ym,s=150,c=col)
    
    # Draw line
    ax1.plot([xc,xm],[yc,ym],c=col)

def plotCartPosition(t, data, col, ax):
    xc = data[:,0]
    ax.plot(t, xc)

def plotBarAngle(t, data, col, ax):
    xc = data[:,2]
    ax.plot(t, xc)
    
def animate2(i,data):
    colors = ['k','b','r']
    ax1.clear()
    for k, d in enumerate(data):
        drawCartPendulum(i, d, colors[k] , ax1)
    ax1.legend(("$Nonlinear^{(c)}$","$LTI^{(c)}$","$LTI^{(d)}$"))
    plt.xlim(-1, 1)

# %%
tmax/Nt*1000
# Out:
# 25.0

# %%
#plt.plot(t, deqn[:,1])
fig1 = plt.figure(1)
ax1 = fig1.add_subplot(1, 1, 1)
an = ani.FuncAnimation(fig1, animate2, frames=len(res[0]),fargs=(res, ), interval=tmax/Nt*1000, repeat=False)
HTML(an.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...

# %%
fig2 = plt.figure(2)
for i, r in enumerate(res):
    ax2 = fig2.add_subplot(3, 1, 1)
    plotCartPosition(t,r,'k',ax2)
    
    ax2 = fig2.add_subplot(3, 1, 2)
    plotBarAngle(t,r,'k',ax2)
# Out:
# /home/sam/.local/lib/python3.5/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
